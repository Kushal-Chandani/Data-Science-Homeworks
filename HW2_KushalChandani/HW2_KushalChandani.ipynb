# %% [markdown]
# ## Data Science HW2
# ### Kushal Chandani (kc07535)
# ### kc07535@st.habib.edu.pk

# %%
import pandas as pd

# %% [markdown]
# # Assignment Data File

# %%
import pandas as pd

# %%
df = pd.read_csv('580SurveyCleanup.csv')

# %%
df.head()
# Out:
#   Unnamed: 0       Unnamed: 1 Unnamed: 2          Unnamed: 3   Unnamed: 4  \
# 0        No.             Time     Status  Duration (Seconds)  Access Code
# 1          1  10/3/20 5:49 PM  Completed               11646          NaN
# 2          2  10/3/20 5:49 PM  Completed                 113          NaN
# 3          3  10/3/20 5:49 PM  Completed                 572          NaN
# 4          4  10/3/20 5:50 PM  Completed                 365          NaN
#
#       Unnamed: 5      Unnamed: 6     Unnamed: 7 Unnamed: 8  \
# 0  Email Address      IP Address        Country     Region
# 1            NaN  100.36.167.226  United States   Virginia
# 2            NaN   98.169.26.134  United States   Virginia
# 3            NaN    98.169.52.23  United States   Virginia
# 4            NaN  69.255.182.253  United States   Virginia
#
#                Unnamed: 9  ...             Q11.1         Q11.2  \
# 0  City / Town / District  ...  Some familiarity  Average user
# ...

# %%
df_1 = df.iloc[:,1:12]

# %%
df_1.head()
# Out:
#         Unnamed: 1 Unnamed: 2          Unnamed: 3   Unnamed: 4     Unnamed: 5  \
# 0             Time     Status  Duration (Seconds)  Access Code  Email Address
# 1  10/3/20 5:49 PM  Completed               11646          NaN            NaN
# 2  10/3/20 5:49 PM  Completed                 113          NaN            NaN
# 3  10/3/20 5:49 PM  Completed                 572          NaN            NaN
# 4  10/3/20 5:50 PM  Completed                 365          NaN            NaN
#
#        Unnamed: 6     Unnamed: 7 Unnamed: 8              Unnamed: 9  \
# 0      IP Address        Country     Region  City / Town / District
# 1  100.36.167.226  United States   Virginia                 Fairfax
# 2   98.169.26.134  United States   Virginia                 Fairfax
# 3    98.169.52.23  United States   Virginia          Greenway Downs
# 4  69.255.182.253  United States   Virginia             Gainesville
#
#   Unnamed: 10 Unnamed: 11
# 0    Latitude   Longitude
# 1    -77.2891     38.8209
# ...

# %% [markdown]
# ### Replacing header with first row

# %%
df_1.columns
# Out:
# Index(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11'],
#       dtype='object')

# %%
df_1.columns = df_1.iloc[0]
df_1 = df_1[1:]

# %%
df_1.head()
# Out:
# 0             Time     Status Duration (Seconds) Access Code Email Address  \
# 1  10/3/20 5:49 PM  Completed              11646         NaN           NaN
# 2  10/3/20 5:49 PM  Completed                113         NaN           NaN
# 3  10/3/20 5:49 PM  Completed                572         NaN           NaN
# 4  10/3/20 5:50 PM  Completed                365         NaN           NaN
# 5  10/3/20 5:51 PM  Completed                 92         NaN           NaN
#
# 0      IP Address        Country    Region City / Town / District  Latitude  \
# 1  100.36.167.226  United States  Virginia                Fairfax  -77.2891
# 2   98.169.26.134  United States  Virginia                Fairfax   -77.263
# 3    98.169.52.23  United States  Virginia         Greenway Downs  -77.2331
# 4  69.255.182.253  United States  Virginia            Gainesville  -77.6308
# 5  138.88.108.230  United States       NaN                    NaN   -97.822
#
# 0 Longitude
# 1   38.8209
# 2   38.8605
# 3   38.9645
# ...

# %% [markdown]
# ### Getting Question 1 coulumns

# %%
df2 = df.iloc[:,[12,13]]

# %%
df2.head()
# Out:
#     Q1  Q1.1
# 0  2.0   4.0
# 1  NaN   1.0
# 2  1.0   NaN
# 3  1.0   NaN
# 4  1.0   NaN

# %% [markdown]
# ### Replacing header with first row

# %%
df2.columns = df2.iloc[0].astype(str)
df2 = df2[1:]

# %%
df2.head()
# Out:
# 0  2.0  4.0
# 1  NaN  1.0
# 2  1.0  NaN
# 3  1.0  NaN
# 4  1.0  NaN
# 5  1.0  NaN

# %%
#### Part 1 of Homework

#Question 2 Formatting

dfg = df.iloc[:, [14, 15, 16, 17]]
dfg.columns = dfg.iloc[0].astype(str)
dfg = dfg[1:]

columns_to_replace = ['Male', 'Female', 'NonBinary', 'Prefer not to answer']

for column in columns_to_replace:
    dfg[column] = dfg[column].replace('1', column)

dfg = dfg.fillna('')
dfg['Q2'] = dfg.apply(lambda row: ''.join(row.astype(str)), axis=1)
dfg = dfg[['Q2']]

dfg.head()
# Out:
# 0                    Q2
# 1                Female
# 2                Female
# 3                  Male
# 4  Prefer not to answer
# 5                  Male

# %%
# Question 8 Formatting

dfl = df.iloc[:, [23, 24, 25, 26]]
dfl.columns = dfl.iloc[0].astype(str)
dfl = dfl[1:]

columns_to_replace = ['Microsoft/Windows', 'Apple/MacBook', 'Other']

for column in columns_to_replace:
    dfl[column] = dfl[column].replace(['0', '1', '2'], column[:3])

dfl = dfl.fillna('')
dfl['Q8'] = dfl.apply(lambda row: ''.join(row.astype(str)), axis=1)
dfl = dfl[['Q8']]

dfl.head()
# Out:
# 0   Q8
# 1  App
# 2  App
# 3  App
# 4  Mic
# 5  App

# %%
# Question 9 Formatting

dff = df.iloc[:, [27, 28, 29]]
dff.columns = dff.iloc[0].astype(str)
dff = dff[1:]

columns_to_replace = ['Yes, Full Time', 'Working, but not Full Time', 'Not Working while attending Mason']

for column in columns_to_replace:
    if column == 'Yes, Full Time':
        dff[column] = dff[column].replace('1', 'full time')
    else:
        dff[column] = dff[column].replace(['0', '1', '2'], 'part time' if column == 'Working, but not Full Time' else 'not working')

dff = dff.fillna('')
dff['Q9'] = dff.apply(lambda row: ''.join(row.astype(str)), axis=1)
dff = dff[['Q9']]

dff.head()
# Out:
# 0           Q9
# 1  not working
# 2    part time
# 3    full time
# 4  not working
# 5    full time

# %%
# Question 10 Formatting

dfc = df.iloc[:, [30, 31, 32, 33, 34]]
dfc.columns = dfc.iloc[0].astype(str)
dfc = dfc[1:]

columns_to_replace = ['Little/none', 'Some familiarity', 'Average user', 'Frequent use for projects', 'Fluent/expert']

for column in columns_to_replace:
    if column == 'Little/none':
        dfc[column] = dfc[column].replace('1', 'little/none')
    else:
        dfc[column] = dfc[column].replace(['0', '1', '2'], 'some' if column == 'Some familiarity' else 'average' if column == 'Average user' else 'frequent user' if column == 'Frequent use for projects' else 'expert')

dfc = dfc.fillna('')
dfc['Q10'] = dfc.apply(lambda row: ''.join(row.astype(str)), axis=1)
dfc = dfc[['Q10']]

dfc.head()
# Out:
# 0      Q10
# 1     some
# 2  average
# 3     some
# 4  average
# 5     some

# %%
# Question 11 Formatting

dfr = df.iloc[:, [35, 36, 37, 38, 39]]
dfr.columns = dfr.iloc[0].astype(str)
dfr = dfr[1:]

columns_to_replace = ['Little/none', 'Some familiarity', 'Average user', 'Frequent use for projects', 'Fluent/expert']

for column in columns_to_replace:
    if column == 'Little/none':
        dfr[column] = dfr[column].replace('1', 'little/none')
    else:
        dfr[column] = dfr[column].replace(['0', '1', '2'], 'some' if column == 'Some familiarity' else 'average' if column == 'Average user' else 'frequent user' if column == 'Frequent use for projects' else 'expert')

dfr = dfr.fillna('')
dfr['Q11'] = dfr.apply(lambda row: ''.join(row.astype(str)), axis=1)
dfr = dfr[['Q11']]

dfr.head()
# Out:
# 0            Q11
# 1    little/none
# 2        average
# 3    little/none
# 4  frequent user
# 5           some

# %%
# Question 12 Formatting

dfp = df.iloc[:, [40, 41, 42, 43, 44]]
dfp.columns = dfp.iloc[0].astype(str)
dfp = dfp[1:]

columns_to_replace = ['Little/none', 'Some familiarity', 'Average user', 'Frequent use for projects', 'Fluent/expert']

for column in columns_to_replace:
    if column == 'Little/none':
        dfp[column] = dfp[column].replace('1', 'little/none')
    else:
        dfp[column] = dfp[column].replace(['0', '1', '2'], 'some' if column == 'Some familiarity' else 'average' if column == 'Average user' else 'frequent user' if column == 'Frequent use for projects' else 'expert')

dfp = dfp.fillna('')
dfp['Q12'] = dfp.apply(lambda row: ''.join(row.astype(str)), axis=1)
dfp = dfp[['Q12']]

dfp.head()
# Out:
# 0          Q12
# 1         some
# 2  little/none
# 3      average
# 4         some
# 5      average

# %% [markdown]
# ### Replace every "1" value with its respective column name

# %%
df3 = df2.loc[:, '2.0':'4.0'].replace(1, pd.Series(df2.columns, df2.columns)).fillna('')

# %%
df3
# Out:
# 0   2.0  4.0
# 1        4.0
# 2   2.0
# 3   2.0
# 4   2.0
# 5   2.0
# 6   2.0
# 7   2.0
# 8   2.0
# 9   2.0
# 10       4.0
# 11  2.0
# 12       4.0
# 13  2.0
# 14  2.0
# 15       4.0
# 16       4.0
# 17  2.0
# 18  2.0
# 19       4.0
# 20       4.0
# 21       4.0
# 22  2.0
# 23       4.0
# 24       4.0
# 25       4.0
# 26  2.0
# 27  2.0
# 28       4.0
# 29       4.0
# 30  2.0
# 31       4.0
# 32  2.0
# 33  2.0
# 34       4.0
# 35  2.0
# 36       4.0

# %% [markdown]
# ### concatenate Q1 columns into one final column

# %%
df4 = pd.DataFrame(df3.iloc[:,0] + df3.iloc[:,1])

# %%
df4.head()
# Out:
#      0
# 1  4.0
# 2  2.0
# 3  2.0
# 4  2.0
# 5  2.0

# %%
df4.columns = ['Q1']

# %%
df4.head()
# Out:
#     Q1
# 1  4.0
# 2  2.0
# 3  2.0
# 4  2.0
# 5  2.0

# %%
df5 = pd.concat([df_1,df4],axis=1)

# %%
df5.head()
# Out:
#               Time     Status Duration (Seconds) Access Code Email Address  \
# 1  10/3/20 5:49 PM  Completed              11646         NaN           NaN
# 2  10/3/20 5:49 PM  Completed                113         NaN           NaN
# 3  10/3/20 5:49 PM  Completed                572         NaN           NaN
# 4  10/3/20 5:50 PM  Completed                365         NaN           NaN
# 5  10/3/20 5:51 PM  Completed                 92         NaN           NaN
#
#        IP Address        Country    Region City / Town / District  Latitude  \
# 1  100.36.167.226  United States  Virginia                Fairfax  -77.2891
# 2   98.169.26.134  United States  Virginia                Fairfax   -77.263
# 3    98.169.52.23  United States  Virginia         Greenway Downs  -77.2331
# 4  69.255.182.253  United States  Virginia            Gainesville  -77.6308
# 5  138.88.108.230  United States       NaN                    NaN   -97.822
#
#   Longitude   Q1
# 1   38.8209  4.0
# 2   38.8605  2.0
# ...

# %%
df5
# Out:
#                 Time      Status Duration (Seconds) Access Code Email Address  \
# 1    10/3/20 5:49 PM   Completed              11646         NaN           NaN
# 2    10/3/20 5:49 PM   Completed                113         NaN           NaN
# 3    10/3/20 5:49 PM   Completed                572         NaN           NaN
# 4    10/3/20 5:50 PM   Completed                365         NaN           NaN
# 5    10/3/20 5:51 PM   Completed                 92         NaN           NaN
# 6    10/3/20 5:59 PM  Incomplete                221         NaN           NaN
# 7    10/3/20 6:23 PM   Completed             115983         NaN           NaN
# 8    10/3/20 7:10 PM  Incomplete                 40         NaN           NaN
# 9    10/3/20 7:25 PM   Completed                137         NaN           NaN
# 10   10/3/20 7:56 PM  Incomplete                179         NaN           NaN
# 11   10/3/20 8:14 PM   Completed                127         NaN           NaN
# ...

# %%
dfx = df.iloc[:,[18,19,20,21,22]]
dfx = dfx[1:]

dfv = df.iloc[:, [45]]
dfv = dfv[1:].fillna('empty')

dfm = df.iloc[:,[0]]
dfm = dfm[1:]
dfm.columns = ['Number']

dfFinal = pd.concat([dfm, df5, dfg, dfx, dfl, dff, dfc, dfr, dfp, dfv], axis = 1)
dfFinal

dfFinal.to_csv('formatted_580SurveyCleanupFinal.csv', index = False)

# %% [markdown]
# ### Checking Null or Nan values

# %%
df5.isnull().sum()
# Out:
# Time                       0
# Status                     0
# Duration (Seconds)         0
# Access Code               36
# Email Address             36
# IP Address                 0
# Country                    0
# Region                     4
# City / Town / District     5
# Latitude                   0
# Longitude                  0
# Q1                         0
# dtype: int64

# %%
#Part 2 of Homework

import numpy as np

da = pd.read_csv('formatted_580SurveyCleanupFinal.csv')
da.isnull().sum()
# Out:
# Number                     0
# Time                       0
# Status                     0
# Duration (Seconds)         0
# Access Code               36
# Email Address             36
# IP Address                 0
# Country                    0
# Region                     4
# City / Town / District     5
# Latitude                   0
# Longitude                  0
# Q1                         0
# Q2                         0
# Q3                         0
# Q4                         1
# Q5                         2
# Q6                         2
# Q7                         3
# Q8                         3
# Q9                         3
# Q10                        3
# Q11                        3
# Q12                        3
# Q13                        0
# dtype: int64

# %%
#Dropping empty tables

da = da.drop(['Access Code', 'Email Address'], axis = 1)

# %%
#replacing values

da['Q4'] = da['Q4'].replace({'7O': '70', '6l': '61', '5.2': '52'})
da['Q4'].fillna(da['Q4'].mode()[0], inplace=True)

# %%
da.head()
# Out:
#    Number             Time     Status  Duration (Seconds)      IP Address  \
# 0       1  10/3/20 5:49 PM  Completed               11646  100.36.167.226
# 1       2  10/3/20 5:49 PM  Completed                 113   98.169.26.134
# 2       3  10/3/20 5:49 PM  Completed                 572    98.169.52.23
# 3       4  10/3/20 5:50 PM  Completed                 365  69.255.182.253
# 4       5  10/3/20 5:51 PM  Completed                  92  138.88.108.230
#
#          Country    Region City / Town / District  Latitude  Longitude  ...  \
# 0  United States  Virginia                Fairfax  -77.2891    38.8209  ...
# 1  United States  Virginia                Fairfax  -77.2630    38.8605  ...
# 2  United States  Virginia         Greenway Downs  -77.2331    38.9645  ...
# 3  United States  Virginia            Gainesville  -77.6308    38.8175  ...
# 4  United States       NaN                    NaN  -97.8220    37.7510  ...
#
# ...

# %%
#filling columns

columns_to_fill = ['Q8', 'Q9', 'Q10', 'Q11', 'Q12']

for column in columns_to_fill:
    da[column].fillna(da[column].mode()[0], inplace=True)

# %%
da.head()
# Out:
#    Number             Time     Status  Duration (Seconds)      IP Address  \
# 0       1  10/3/20 5:49 PM  Completed               11646  100.36.167.226
# 1       2  10/3/20 5:49 PM  Completed                 113   98.169.26.134
# 2       3  10/3/20 5:49 PM  Completed                 572    98.169.52.23
# 3       4  10/3/20 5:50 PM  Completed                 365  69.255.182.253
# 4       5  10/3/20 5:51 PM  Completed                  92  138.88.108.230
#
#          Country    Region City / Town / District  Latitude  Longitude  ...  \
# 0  United States  Virginia                Fairfax  -77.2891    38.8209  ...
# 1  United States  Virginia                Fairfax  -77.2630    38.8605  ...
# 2  United States  Virginia         Greenway Downs  -77.2331    38.9645  ...
# 3  United States  Virginia            Gainesville  -77.6308    38.8175  ...
# 4  United States       NaN                    NaN  -97.8220    37.7510  ...
#
# ...

# %%
# filling missing values 

columns_to_fill = ['Region', 'City / Town / District']

for column in columns_to_fill:
    da[column].fillna(da[column].mode()[0], inplace=True)

# %%
da.head()
# Out:
#    Number             Time     Status  Duration (Seconds)      IP Address  \
# 0       1  10/3/20 5:49 PM  Completed               11646  100.36.167.226
# 1       2  10/3/20 5:49 PM  Completed                 113   98.169.26.134
# 2       3  10/3/20 5:49 PM  Completed                 572    98.169.52.23
# 3       4  10/3/20 5:50 PM  Completed                 365  69.255.182.253
# 4       5  10/3/20 5:51 PM  Completed                  92  138.88.108.230
#
#          Country    Region City / Town / District  Latitude  Longitude  ...  \
# 0  United States  Virginia                Fairfax  -77.2891    38.8209  ...
# 1  United States  Virginia                Fairfax  -77.2630    38.8605  ...
# 2  United States  Virginia         Greenway Downs  -77.2331    38.9645  ...
# 3  United States  Virginia            Gainesville  -77.6308    38.8175  ...
# 4  United States  Virginia                Fairfax  -97.8220    37.7510  ...
#
# ...

# %%
da['Q3'] = da['Q3'].str.replace(' ', '') #filling spaces with Q3
da['Q3'] = da['Q3'].replace('1993', '30') #replace 1993 with 30
da['Q3'].fillna(da['Q3'].mode()[0], inplace=True) #filling missing values with mode

# %%
da.head()
# Out:
#    Number             Time     Status  Duration (Seconds)      IP Address  \
# 0       1  10/3/20 5:49 PM  Completed               11646  100.36.167.226
# 1       2  10/3/20 5:49 PM  Completed                 113   98.169.26.134
# 2       3  10/3/20 5:49 PM  Completed                 572    98.169.52.23
# 3       4  10/3/20 5:50 PM  Completed                 365  69.255.182.253
# 4       5  10/3/20 5:51 PM  Completed                  92  138.88.108.230
#
#          Country    Region City / Town / District  Latitude  Longitude  ...  \
# 0  United States  Virginia                Fairfax  -77.2891    38.8209  ...
# 1  United States  Virginia                Fairfax  -77.2630    38.8605  ...
# 2  United States  Virginia         Greenway Downs  -77.2331    38.9645  ...
# 3  United States  Virginia            Gainesville  -77.6308    38.8175  ...
# 4  United States  Virginia                Fairfax  -97.8220    37.7510  ...
#
# ...

# %%
da['Q6'] = da['Q6'].str.title().str.strip().replace({
    'Bachelor of engineering ': 'Engineering',
    'Engineering ': 'Engineering',
    'Cse': 'Computer Science and Engineering',
    'Computer science engineering ': 'Computer Science and Engineering',
    'Computer engineering': 'Computer Science and Engineering',
    'B.tech in cs': 'Computer Science',
    'Criminology law and soci': 'Criminology law and social sciences',
    'Ece': 'Electrical and Computer Engineering',
    'Economic': 'Economics',
    'Yes': np.NaN,
})

da['Q6'].fillna(da['Q6'].mode()[0], inplace=True)

# %%
da
# Out:
#     Number              Time      Status  Duration (Seconds)       IP Address  \
# 0        1   10/3/20 5:49 PM   Completed               11646   100.36.167.226
# 1        2   10/3/20 5:49 PM   Completed                 113    98.169.26.134
# 2        3   10/3/20 5:49 PM   Completed                 572     98.169.52.23
# 3        4   10/3/20 5:50 PM   Completed                 365   69.255.182.253
# 4        5   10/3/20 5:51 PM   Completed                  92   138.88.108.230
# 5        6   10/3/20 5:59 PM  Incomplete                 221    108.56.134.80
# 6        7   10/3/20 6:23 PM   Completed              115983   108.48.175.220
# 7        8   10/3/20 7:10 PM  Incomplete                  40    173.67.199.85
# 8        9   10/3/20 7:25 PM   Completed                 137     74.96.114.12
# 9       10   10/3/20 7:56 PM  Incomplete                 179    107.77.241.32
# 10      11   10/3/20 8:14 PM   Completed                 127   138.88.182.245
# ...

# %%
da['Q7'].fillna('Not responded', inplace=True)

da['Q8'] = da['Q8'].replace('Microsoft/Windows', 'Windows')
da['Q8'] = da['Q8'].replace('Apple/MacBook', 'Macbook')
da['Q8'] = da['Q8'].replace('Acer/Windows', 'Windows')

da['Q13'].fillna('Not responded', inplace=True)

# %%
da.head()
# Out:
#    Number             Time     Status  Duration (Seconds)      IP Address  \
# 0       1  10/3/20 5:49 PM  Completed               11646  100.36.167.226
# 1       2  10/3/20 5:49 PM  Completed                 113   98.169.26.134
# 2       3  10/3/20 5:49 PM  Completed                 572    98.169.52.23
# 3       4  10/3/20 5:50 PM  Completed                 365  69.255.182.253
# 4       5  10/3/20 5:51 PM  Completed                  92  138.88.108.230
#
#          Country    Region City / Town / District  Latitude  Longitude  ...  \
# 0  United States  Virginia                Fairfax  -77.2891    38.8209  ...
# 1  United States  Virginia                Fairfax  -77.2630    38.8605  ...
# 2  United States  Virginia         Greenway Downs  -77.2331    38.9645  ...
# 3  United States  Virginia            Gainesville  -77.6308    38.8175  ...
# 4  United States  Virginia                Fairfax  -97.8220    37.7510  ...
#
# ...

# %%
da['Q5'] = da['Q5'].str.capitalize()
da['Q5'] = da['Q5'].fillna('N/A', inplace=False)
da['Q5'] = da['Q5'].replace(['Usa', 'United states', 'United states ', 'Us'], 'USA')
da['Q5'] = da['Q5'].replace(['United states ; pakistan '], 'USA ; Pakistan')

# %%
da.head()
# Out:
#    Number             Time     Status  Duration (Seconds)      IP Address  \
# 0       1  10/3/20 5:49 PM  Completed               11646  100.36.167.226
# 1       2  10/3/20 5:49 PM  Completed                 113   98.169.26.134
# 2       3  10/3/20 5:49 PM  Completed                 572    98.169.52.23
# 3       4  10/3/20 5:50 PM  Completed                 365  69.255.182.253
# 4       5  10/3/20 5:51 PM  Completed                  92  138.88.108.230
#
#          Country    Region City / Town / District  Latitude  Longitude  ...  \
# 0  United States  Virginia                Fairfax  -77.2891    38.8209  ...
# 1  United States  Virginia                Fairfax  -77.2630    38.8605  ...
# 2  United States  Virginia         Greenway Downs  -77.2331    38.9645  ...
# 3  United States  Virginia            Gainesville  -77.6308    38.8175  ...
# 4  United States  Virginia                Fairfax  -97.8220    37.7510  ...
#
# ...

# %%
#Making CSV file

da.to_csv('cleaned_580SurveyCleanupFinal.csv', index = False)

# %% [markdown]
# ### Count Unique Values in a column

# %%
df5['Q1'].value_counts()
# Out:
# Q1
# 2.0    20
# 4.0    16
# Name: count, dtype: int64

# %% [markdown]
# ### Summary Statistics

# %%
df5.describe()
# Out:
#                    Time     Status Duration (Seconds) Access Code
# count                36         36                 36           0  \
# unique               34          2                 36           0
# top     10/3/20 5:49 PM  Completed              11646         NaN
# freq                  3         32                  1         NaN
#
#        Email Address     IP Address        Country    Region
# count              0             36             36        32  \
# unique             0             34              1         3
# top              NaN  108.56.134.80  United States  Virginia
# freq             NaN              2             36        25
#
#        City / Town / District  Latitude Longitude   Q1
# count                      31        36        36   36
# unique                     17        24        24    2
# top                   Fairfax  -77.2866   38.7851  2.0
# freq                        6         4         4   20

# %%
df5['Q1'].describe()
# Out:
# count      36
# unique      2
# top       2.0
# freq       20
# Name: Q1, dtype: object

# %%
#Part 3 of homework

da.describe()
# Out:
#           Number  Duration (Seconds)   Latitude  Longitude         Q1
# count  36.000000           36.000000  36.000000  36.000000  36.000000
# mean   18.500000         7571.027778 -80.093406  38.562475   2.888889
# std    10.535654        28292.029740   7.151399   1.101628   1.007905
# min     1.000000           40.000000 -97.822000  32.778700   2.000000
# 25%     9.750000          171.500000 -77.374475  38.730625   2.000000
# 50%    18.500000          263.000000 -77.286600  38.835700   2.000000
# 75%    27.250000          537.500000 -77.226325  38.931100   4.000000
# max    36.000000       128253.000000 -76.557000  39.462400   4.000000

# %%
print('unique values = ',da['Q1'].unique())
print('values = ' ,da['Q1'].value_counts())
print('Mode = ' ,da['Q1'].mode())
da['Q1'].describe()         #Q1 contains defined labels
# Out:
# unique values =  [4. 2.]
# values =  2.0    20
# 4.0    16
# Name: Q1, dtype: int64
# Mode =  0    2.0
# Name: Q1, dtype: float64
# count    36.000000
# mean      2.888889
# std       1.007905
# min       2.000000
# 25%       2.000000
# 50%       2.000000
# 75%       4.000000
# max       4.000000
# Name: Q1, dtype: float64

# %%
print('unique values = ',da['Q2'].unique())
print('values = ' ,da['Q2'].value_counts())
print('Mode = ' ,da['Q2'].mode())
da['Q2'].describe()         #Q2 also contains defined labels
# Out:
# unique values =  ['Female' 'Male' 'Prefer not to answer' 'NonBinary']
# values =  Male                    18
# Female                  16
# Prefer not to answer     1
# NonBinary                1
# Name: Q2, dtype: int64
# Mode =  0    Male
# Name: Q2, dtype: object
# count       36
# unique       4
# top       Male
# freq        18
# Name: Q2, dtype: object

# %%
print('unique values = ', da['Q3'].unique())
print('values = ', da['Q3'].value_counts())
print('Mode = ', da['Q3'].mode())
da['Q3'].describe()                   #The age column shows that most people have age more than 20 and less than 25
# Out:
# unique values =  ['23' '24' '40' '26' '30' '25' '31' '22' '27' '28' '35' '55']
# values =  23    8
# 25    6
# 24    5
# 26    3
# 30    3
# 40    2
# 22    2
# 27    2
# 28    2
# 31    1
# 35    1
# 55    1
# Name: Q3, dtype: int64
# Mode =  0    23
# Name: Q3, dtype: object
# count     36
# unique    12
# top       23
# freq       8
# Name: Q3, dtype: object

# %%
print('unique values = ', da['Q4'].unique())
print('values = ', da['Q4'].value_counts())
print('Mode = ', da['Q4'].mode())
da['Q4'].describe()               #The height column indicates that more people have height between 60 and 75 inches.
# Out:
# unique values =  ['63' '59' '70' '66' '52' '71' '69' '67' '72' '68' '60' '74' '65' '75'
#  '61' '64' '56' '73']
# values =  66    6
# 70    5
# 67    5
# 68    3
# 71    3
# 72    2
# 65    1
# 56    1
# 64    1
# 61    1
# 75    1
# 63    1
# 74    1
# 60    1
# 59    1
# 69    1
# 52    1
# 73    1
# Name: Q4, dtype: int64
# Mode =  0    66
# Name: Q4, dtype: object
# count     36
# unique    18
# top       66
# freq       6
# Name: Q4, dtype: object

# %%
print('unique values = ', da['Q5'].unique())
print('values = ', da['Q5'].value_counts())
print('Mode = ', da['Q5'].mode())
da['Q5'].describe()        #The citizenship column shows that their are more people from india and overall data is very diverse in terms of countries.
# Out:
# unique values =  ['Taiwan' 'India' 'South korea' 'USA' 'N/A' 'Pakistan' 'China'
#  'Uzbekistan ' 'Romania' 'Uzbekistan' 'India ' 'Ethiopia' 'Nigeria '
#  'Nigeria' 'USA ; Pakistan' 'Vietnam']
# values =  India             9
# USA               9
# Taiwan            2
# N/A               2
# China             2
# Uzbekistan        2
# South korea       1
# Pakistan          1
# Uzbekistan        1
# Romania           1
# India             1
# Ethiopia          1
# Nigeria           1
# Nigeria           1
# USA ; Pakistan    1
# Vietnam           1
# Name: Q5, dtype: int64
# Mode =  0    India
# 1      USA
# Name: Q5, dtype: object
# count        36
# unique       16
# top       India
# freq          9
# Name: Q5, dtype: object

# %%
print('unique values = ', da['Q6'].unique())
print('values = ', da['Q6'].value_counts())
print('Mode = ', da['Q6'].mode())
da['Q6'].describe()      #The degree column shows that most people have economics as their degree and we can see again the diversity in the data.
# Out:
# unique values =  ['Economics' 'Finance' 'Computer Applications' 'Business Management'
#  'Economics With Finance' 'Bit' 'Computer Engineering' 'Biology'
#  'Computer Science and Engineering' 'Management' 'Engineering'
#  'Accounting And Isom' 'Statistics' 'Computer Science'
#  'Mathematics & Statistics' 'Systems Engineering' 'Civil Engineering'
#  'Electrical and Computer Engineering' 'Quantity Surveying'
#  'Bachelor Of Engineering' 'B.Tech In Cs' 'Bs Accounting'
#  'Criminology Law And Soci' 'Psychology']
# values =  Economics                              8
# Finance                                3
# Computer Science                       2
# Economics With Finance                 2
# Bachelor Of Engineering                2
# Criminology Law And Soci               1
# Bs Accounting                          1
# B.Tech In Cs                           1
# Quantity Surveying                     1
# Electrical and Computer Engineering    1
# Civil Engineering                      1
# ...

# %%
print('unique values = ', da['Q7'].unique())
print('values = ', da['Q7'].value_counts())
print('Mode = ', da['Q7'].mode())
da['Q7'].describe()                #The data contains numerous dates hence nothing of any sort can be determined
# Out:
# unique values =  ['2021-12-31' '2021-05-01' '2022-06-01' '2021-01-01' 'Not responded'
#  '2022-07-15' '2021-12-15' '2022-05-01' '2021-05-31' '2021-08-26'
#  '2021-12-25' '2022-05-31' '2021-01-12' '2021-12-20' '2022-04-16'
#  '2021-12-18' '2021-05-14' '2022-12-19' '2021-05-30' '2021-12-11'
#  '2023-05-24' '2021-12-30' '2021-12-21' '2022-05-15' '2022-12-12']
# values =  2021-12-31       3
# Not responded    3
# 2022-05-01       3
# 2021-12-20       3
# 2021-12-18       2
# 2021-12-15       2
# 2021-05-01       2
# 2022-05-15       1
# 2021-12-21       1
# 2021-12-30       1
# 2023-05-24       1
# 2021-12-11       1
# 2021-05-30       1
# 2022-12-19       1
# 2021-05-14       1
# 2021-01-12       1
# 2022-04-16       1
# 2022-05-31       1
# 2021-12-25       1
# 2021-08-26       1
# 2021-05-31       1
# 2022-07-15       1
# 2021-01-01       1
# 2022-06-01       1
# 2022-12-12       1
# Name: Q7, dtype: int64
# Mode =  0       2021-12-20
# 1       2021-12-31
# 2       2022-05-01
# ...

# %%
print('unique values = ', da['Q8'].unique())
print('values = ', da['Q8'].value_counts())
print('Mode = ', da['Q8'].mode())
da['Q8'].describe()      #The data just shows the type of pcs people use where Mic (microsoft) and App (Apple) and more people use Mic
# Out:
# unique values =  ['App' 'Mic' 'MicApp' 'OthAcer/Windows']
# values =  Mic                24
# App                 8
# MicApp              3
# OthAcer/Windows     1
# Name: Q8, dtype: int64
# Mode =  0    Mic
# Name: Q8, dtype: object
# count      36
# unique      4
# top       Mic
# freq       24
# Name: Q8, dtype: object

# %%
print('unique values = ', da['Q9'].unique())
print('values = ', da['Q9'].value_counts())
print('Mode = ', da['Q9'].mode())
da['Q9'].describe()         #The data indicates that most people are not working, howver the class also has full time and part time students working
# Out:
# unique values =  ['not working' 'part time' 'full time']
# values =  not working    20
# full time      11
# part time       5
# Name: Q9, dtype: int64
# Mode =  0    not working
# Name: Q9, dtype: object
# count              36
# unique              3
# top       not working
# freq               20
# Name: Q9, dtype: object

# %%
print('unique values = ', da['Q10'].unique())
print('values = ', da['Q10'].value_counts())
print('Mode = ', da['Q10'].mode())
da['Q10'].describe()                     #The data indicates that people using python have average skillset however more users know python.
# Out:
# unique values =  ['some' 'average' 'little/none' 'frequent user']
# values =  average          18
# some             12
# little/none       4
# frequent user     2
# Name: Q10, dtype: int64
# Mode =  0    average
# Name: Q10, dtype: object
# count          36
# unique          4
# top       average
# freq           18
# Name: Q10, dtype: object

# %%
print('unique values = ', da['Q11'].unique())
print('values = ', da['Q11'].value_counts())
print('Mode = ', da['Q11'].mode())
da['Q11'].describe()                #The data indicates that people have less expertise in R language and the mode is average.
# Out:
# unique values =  ['little/none' 'average' 'frequent user' 'some' 'expert']
# values =  average          12
# little/none       8
# some              8
# frequent user     7
# expert            1
# Name: Q11, dtype: int64
# Mode =  0    average
# Name: Q11, dtype: object
# count          36
# unique          5
# top       average
# freq           12
# Name: Q11, dtype: object

# %%
print('unique values = ', da['Q12'].unique())
print('values = ', da['Q12'].value_counts())
print('Mode = ', da['Q12'].mode())
da['Q12'].describe()             #The data indicates a lot of people use SQl however the mode of the survey remains average.
# Out:
# unique values =  ['some' 'little/none' 'average' 'frequent user']
# values =  average          18
# some             10
# little/none       5
# frequent user     3
# Name: Q12, dtype: int64
# Mode =  0    average
# Name: Q12, dtype: object
# count          36
# unique          4
# top       average
# freq           18
# Name: Q12, dtype: object
